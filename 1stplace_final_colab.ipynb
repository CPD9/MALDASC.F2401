# %%
# !pip install -q kaggle
# !mkdir -p ./kaggle
# !cp kaggle.json ./kaggle/
# !chmod 600 ./kaggle/kaggle.json
# !cat ./kaggle/kaggle.json
# ! kaggle datasets list
# !kaggle datasets download -d haqishen/timm-20220211

# %%
# !unzip ./timm-20221011.zip -d ./timm-20221011
# !cp -r ./timm-20221011/pytorch-image-models-master/timm/ ./timm4smp
# Out:
# Archive:  ./timm-20221011.zip
#   inflating: ./timm-20221011/pytorch-image-models-master/.gitattributes
#   inflating: ./timm-20221011/pytorch-image-models-master/.github/FUNDING.yml
#   inflating: ./timm-20221011/pytorch-image-models-master/.github/ISSUE_TEMPLATE/bug_report.md
#   inflating: ./timm-20221011/pytorch-image-models-master/.github/ISSUE_TEMPLATE/config.yml
#   inflating: ./timm-20221011/pytorch-image-models-master/.github/ISSUE_TEMPLATE/feature_request.md
#   inflating: ./timm-20221011/pytorch-image-models-master/.github/workflows/tests.yml
#   inflating: ./timm-20221011/pytorch-image-models-master/.gitignore
#   inflating: ./timm-20221011/pytorch-image-models-master/LICENSE
#   inflating: ./timm-20221011/pytorch-image-models-master/MANIFEST.in
#   inflating: ./timm-20221011/pytorch-image-models-master/README.md
#   inflating: ./timm-20221011/pytorch-image-models-master/avg_checkpoints.py
#   inflating: ./timm-20221011/pytorch-image-models-master/benchmark.py
#   inflating: ./timm-20221011/pytorch-image-models-master/bulk_runner.py
#   inflating: ./timm-20221011/pytorch-image-models-master/clean_checkpoint.py
#   inflating: ./timm-20221011/pytorch-image-models-master/convert/convert_from_mxnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/convert/convert_nest_flax.py
#   inflating: ./timm-20221011/pytorch-image-models-master/distributed_train.sh
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/archived_changes.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/changes.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/feature_extraction.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/index.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/javascripts/tables.js
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.pages
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/code_snippets.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/generate_readmes.py
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/adversarial-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/advprop.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/big-transfer.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/csp-darknet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/csp-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/csp-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/densenet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/dla.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/dpn.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ecaresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/efficientnet-pruned.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/efficientnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ensemble-adversarial.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ese-vovnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/fbnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-senet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-seresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/gloun-xception.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/hrnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ig-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/inception-resnet-v2.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/inception-v4.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/legacy-se-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/legacy-se-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/legacy-senet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/mixnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/mnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/mobilenet-v2.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/mobilenet-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/nasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/noisy-student.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/pnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/regnetx.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/regnety.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/res2net.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/res2next.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/resnest.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/resnet-d.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/rexnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/se-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/selecsls.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/seresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/skresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/skresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/spnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ssl-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/ssl-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/swsl-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/swsl-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-efficientnet-condconv.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-efficientnet-lite.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-efficientnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-mixnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tf-mobilenet-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/tresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/vision-transformer.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/wide-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/.templates/models/xception.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/adversarial-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/advprop.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/big-transfer.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/csp-darknet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/csp-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/csp-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/densenet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/dla.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/dpn.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ecaresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/efficientnet-pruned.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/efficientnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ensemble-adversarial.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ese-vovnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/fbnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-senet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-seresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/gloun-xception.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/hrnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ig-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/inception-resnet-v2.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/inception-v4.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/legacy-se-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/legacy-se-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/legacy-senet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/mixnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/mnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/mobilenet-v2.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/mobilenet-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/nasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/noisy-student.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/pnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/regnetx.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/regnety.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/res2net.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/res2next.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/resnest.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/resnet-d.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/rexnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/se-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/selecsls.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/seresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/skresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/skresnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/spnasnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ssl-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/ssl-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/swsl-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/swsl-resnext.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-efficientnet-condconv.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-efficientnet-lite.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-efficientnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-inception-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-mixnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tf-mobilenet-v3.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/tresnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/vision-transformer.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/wide-resnet.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/models/xception.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/results.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/scripts.md
#   inflating: ./timm-20221011/pytorch-image-models-master/docs/training_hparam_examples.md
#   inflating: ./timm-20221011/pytorch-image-models-master/hubconf.py
#   inflating: ./timm-20221011/pytorch-image-models-master/inference.py
#   inflating: ./timm-20221011/pytorch-image-models-master/mkdocs.yml
#   inflating: ./timm-20221011/pytorch-image-models-master/model-index.yml
#   inflating: ./timm-20221011/pytorch-image-models-master/requirements-docs.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/requirements-modelindex.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/requirements.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/README.md
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-infer-amp-nchw-pt111-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-infer-amp-nchw-pt112-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-infer-amp-nhwc-pt111-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-infer-amp-nhwc-pt112-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-train-amp-nchw-pt111-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-train-amp-nchw-pt112-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-train-amp-nhwc-pt111-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/benchmark-train-amp-nhwc-pt112-cu113-rtx3090.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/generate_csv_results.py
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet21k_goog_synsets.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_a_indices.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_a_synsets.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_r_indices.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_r_synsets.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_real_labels.json
#   inflating: ./timm-20221011/pytorch-image-models-master/results/imagenet_synsets.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/results/model_metadata-in1k.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet-a-clean.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet-a.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet-r-clean.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet-r.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet-real.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenet.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-imagenetv2-matched-frequency.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/results/results-sketch.csv
#   inflating: ./timm-20221011/pytorch-image-models-master/setup.cfg
#   inflating: ./timm-20221011/pytorch-image-models-master/setup.py
#   inflating: ./timm-20221011/pytorch-image-models-master/tests/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/tests/test_layers.py
#   inflating: ./timm-20221011/pytorch-image-models-master/tests/test_models.py
#   inflating: ./timm-20221011/pytorch-image-models-master/tests/test_optim.py
#   inflating: ./timm-20221011/pytorch-image-models-master/tests/test_utils.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/auto_augment.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/config.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/constants.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/dataset.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/dataset_factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/distributed_sampler.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/loader.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/mixup.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/class_map.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/img_extensions.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser_factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser_image_folder.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser_image_in_tar.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser_image_tar.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/parsers/parser_tfds.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/random_erasing.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/real_labels.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/tf_preprocessing.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/transforms.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/data/transforms_factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/loss/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/loss/asymmetric_loss.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/loss/binary_cross_entropy.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/loss/cross_entropy.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/loss/jsd.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/beit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/byoanet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/byobnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/cait.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/coat.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/convit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/convmixer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/convnext.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/crossvit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/cspnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/deit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/densenet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/dla.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/dpn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/edgenext.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/efficientformer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/efficientnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/efficientnet_blocks.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/efficientnet_builder.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/features.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/fx_features.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/gcvit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/ghostnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/gluon_resnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/gluon_xception.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/hardcorenas.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/helpers.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/hrnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/hub.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/inception_resnet_v2.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/inception_v3.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/inception_v4.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/activations.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/activations_jit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/activations_me.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/adaptive_avgmax_pool.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/attention_pool2d.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/blur_pool.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/bottleneck_attn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/cbam.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/classifier.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/cond_conv2d.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/config.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/conv2d_same.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/conv_bn_act.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/create_act.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/create_attn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/create_conv2d.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/create_norm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/create_norm_act.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/drop.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/eca.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/evo_norm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/fast_norm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/filter_response_norm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/gather_excite.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/global_context.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/halo_attn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/helpers.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/inplace_abn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/lambda_layer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/linear.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/median_pool.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/mixed_conv2d.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/ml_decoder.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/mlp.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/non_local_attn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/norm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/norm_act.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/padding.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/patch_embed.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/pool2d_same.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/pos_embed.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/selective_kernel.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/separable_conv.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/space_to_depth.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/split_attn.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/split_batchnorm.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/squeeze_excite.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/std_conv.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/test_time_pool.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/trace_utils.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/layers/weight_init.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/levit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/maxxvit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/mlp_mixer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/mobilenetv3.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/mobilevit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/mvitv2.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/nasnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/nest.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/nfnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pnasnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/poolformer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pruned/ecaresnet101d_pruned.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pruned/ecaresnet50d_pruned.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pruned/efficientnet_b1_pruned.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pruned/efficientnet_b2_pruned.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pruned/efficientnet_b3_pruned.txt
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/pvt_v2.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/registry.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/regnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/res2net.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/resnest.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/resnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/resnetv2.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/rexnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/selecsls.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/senet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/sequencer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/sknet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/swin_transformer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/swin_transformer_v2.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/swin_transformer_v2_cr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/tnt.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/tresnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/twins.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/vgg.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/visformer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/vision_transformer.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/vision_transformer_hybrid.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/vision_transformer_relpos.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/volo.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/vovnet.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/xception.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/xception_aligned.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/models/xcit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/adabelief.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/adafactor.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/adahessian.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/adamp.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/adamw.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/lamb.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/lars.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/lookahead.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/madgrad.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/nadam.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/nvnovograd.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/optim_factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/radam.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/rmsprop_tf.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/optim/sgdp.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/cosine_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/multistep_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/plateau_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/poly_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/scheduler.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/scheduler_factory.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/step_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/scheduler/tanh_lr.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/__init__.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/agc.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/checkpoint_saver.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/clip_grad.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/cuda.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/decay_batch.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/distributed.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/jit.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/log.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/metrics.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/misc.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/model.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/model_ema.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/random.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/utils/summary.py
#   inflating: ./timm-20221011/pytorch-image-models-master/timm/version.py
#   inflating: ./timm-20221011/pytorch-image-models-master/train.py
#   inflating: ./timm-20221011/pytorch-image-models-master/validate.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip ./drive/MyDrive/test_images.zip -d ./test
# Out:
# Archive:  ./drive/MyDrive/test_images.zip
#   inflating: ./test/1.2.826.0.1.3680043.22327/1.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/10.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/100.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/101.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/102.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/103.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/104.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/105.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/106.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/107.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/108.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/109.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/11.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/110.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/111.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/112.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/113.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/114.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/115.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/116.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/117.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/118.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/119.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/12.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/120.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/121.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/122.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/123.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/124.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/125.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/126.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/127.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/128.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/129.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/13.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/130.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/131.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/132.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/133.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/134.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/135.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/136.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/137.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/138.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/139.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/14.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/140.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/141.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/142.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/143.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/144.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/145.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/146.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/147.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/148.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/149.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/15.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/150.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/151.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/152.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/153.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/154.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/155.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/156.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/157.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/158.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/159.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/16.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/160.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/161.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/162.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/163.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/164.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/165.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/166.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/167.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/168.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/169.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/17.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/170.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/171.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/172.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/173.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/174.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/175.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/176.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/177.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/178.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/179.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/18.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/180.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/181.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/182.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/183.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/184.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/185.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/186.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/187.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/188.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/189.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/19.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/190.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/191.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/192.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/193.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/194.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/195.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/196.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/197.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/198.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/199.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/2.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/20.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/200.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/201.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/202.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/203.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/204.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/205.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/206.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/207.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/208.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/209.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/21.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/210.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/211.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/212.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/213.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/214.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/215.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/216.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/217.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/218.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/219.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/22.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/220.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/221.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/222.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/223.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/224.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/225.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/226.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/227.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/228.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/229.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/23.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/230.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/231.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/232.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/233.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/234.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/235.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/236.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/237.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/238.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/239.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/24.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/240.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/241.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/242.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/243.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/244.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/245.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/246.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/247.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/248.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/249.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/25.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/250.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/251.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/252.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/253.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/254.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/255.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/256.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/257.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/258.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/259.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/26.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/260.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/261.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/262.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/263.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/264.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/265.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/266.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/267.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/268.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/269.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/27.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/270.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/271.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/272.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/273.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/274.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/275.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/276.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/277.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/278.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/279.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/28.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/280.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/281.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/282.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/283.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/284.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/285.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/286.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/287.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/288.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/289.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/29.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/290.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/291.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/292.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/293.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/294.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/295.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/296.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/297.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/298.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/299.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/3.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/30.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/300.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/301.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/302.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/303.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/304.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/305.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/306.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/307.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/308.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/309.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/31.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/310.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/311.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/312.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/313.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/32.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/33.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/34.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/35.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/36.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/37.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/38.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/39.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/4.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/40.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/41.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/42.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/43.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/44.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/45.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/46.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/47.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/48.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/49.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/5.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/50.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/51.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/52.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/53.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/54.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/55.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/56.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/57.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/58.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/59.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/6.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/60.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/61.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/62.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/63.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/64.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/65.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/66.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/67.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/68.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/69.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/7.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/70.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/71.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/72.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/73.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/74.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/75.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/76.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/77.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/78.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/79.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/8.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/80.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/81.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/82.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/83.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/84.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/85.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/86.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/87.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/88.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/89.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/9.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/90.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/91.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/92.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/93.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/94.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/95.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/96.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/97.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/98.dcm
#   inflating: ./test/1.2.826.0.1.3680043.22327/99.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/1.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/10.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/100.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/101.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/102.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/103.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/104.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/105.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/106.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/107.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/108.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/109.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/11.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/110.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/111.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/112.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/113.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/114.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/115.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/116.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/117.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/118.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/119.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/12.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/120.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/121.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/122.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/123.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/124.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/125.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/126.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/127.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/128.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/129.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/13.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/130.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/131.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/132.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/133.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/134.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/135.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/136.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/137.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/138.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/139.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/14.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/140.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/141.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/142.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/143.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/144.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/145.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/146.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/147.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/148.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/149.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/15.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/150.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/151.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/152.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/153.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/154.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/155.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/156.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/157.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/158.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/159.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/16.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/160.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/161.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/162.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/163.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/164.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/165.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/166.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/167.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/168.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/169.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/17.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/170.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/171.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/172.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/173.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/174.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/175.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/176.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/177.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/178.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/179.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/18.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/180.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/181.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/182.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/183.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/184.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/185.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/186.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/187.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/188.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/189.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/19.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/190.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/191.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/192.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/193.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/194.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/195.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/196.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/197.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/198.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/199.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/2.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/20.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/200.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/201.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/202.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/203.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/204.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/205.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/206.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/207.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/208.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/209.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/21.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/210.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/211.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/212.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/213.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/214.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/215.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/216.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/217.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/218.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/219.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/22.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/220.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/221.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/222.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/223.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/224.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/225.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/226.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/227.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/228.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/229.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/23.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/230.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/231.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/232.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/233.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/234.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/235.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/236.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/237.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/238.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/239.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/24.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/240.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/241.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/242.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/243.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/244.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/245.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/246.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/247.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/248.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/249.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/25.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/250.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/251.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/252.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/253.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/254.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/255.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/256.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/257.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/258.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/259.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/26.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/260.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/261.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/262.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/263.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/264.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/265.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/266.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/267.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/268.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/269.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/27.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/270.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/271.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/272.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/273.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/274.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/275.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/276.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/277.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/278.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/279.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/28.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/280.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/281.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/282.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/283.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/284.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/285.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/286.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/287.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/288.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/289.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/29.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/290.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/291.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/292.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/293.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/294.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/295.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/296.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/297.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/298.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/299.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/3.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/30.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/300.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/301.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/302.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/303.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/304.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/305.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/306.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/307.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/308.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/309.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/31.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/310.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/311.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/312.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/313.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/314.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/315.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/316.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/317.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/318.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/319.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/32.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/320.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/321.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/322.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/323.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/324.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/325.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/326.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/327.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/328.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/329.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/33.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/330.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/331.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/332.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/333.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/334.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/335.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/336.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/337.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/338.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/339.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/34.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/340.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/341.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/342.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/343.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/344.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/345.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/346.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/347.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/348.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/349.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/35.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/350.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/351.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/352.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/353.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/354.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/355.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/356.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/357.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/358.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/359.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/36.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/360.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/361.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/362.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/363.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/364.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/365.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/366.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/367.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/368.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/369.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/37.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/370.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/371.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/372.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/373.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/374.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/375.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/376.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/377.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/378.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/379.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/38.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/380.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/381.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/382.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/383.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/384.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/385.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/386.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/387.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/388.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/389.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/39.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/390.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/391.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/392.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/393.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/394.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/395.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/396.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/397.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/398.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/399.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/4.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/40.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/400.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/401.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/402.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/403.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/404.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/405.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/406.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/407.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/408.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/409.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/41.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/410.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/411.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/412.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/413.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/414.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/415.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/416.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/417.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/418.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/419.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/42.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/420.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/421.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/422.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/423.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/424.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/425.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/426.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/427.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/428.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/429.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/43.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/430.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/431.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/432.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/433.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/434.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/435.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/436.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/437.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/438.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/439.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/44.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/440.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/441.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/442.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/443.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/444.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/445.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/446.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/447.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/448.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/449.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/45.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/450.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/451.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/452.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/453.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/454.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/455.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/456.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/457.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/458.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/459.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/46.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/460.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/461.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/462.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/463.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/464.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/465.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/466.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/467.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/468.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/469.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/47.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/470.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/471.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/472.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/473.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/474.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/475.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/476.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/477.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/478.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/479.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/48.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/480.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/481.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/482.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/483.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/484.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/485.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/486.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/487.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/488.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/489.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/49.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/490.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/491.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/492.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/493.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/494.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/495.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/496.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/497.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/498.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/499.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/5.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/50.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/500.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/501.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/502.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/503.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/504.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/505.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/506.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/507.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/508.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/509.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/51.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/510.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/511.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/512.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/513.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/514.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/515.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/516.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/517.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/518.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/519.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/52.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/520.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/521.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/522.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/523.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/524.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/525.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/526.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/527.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/528.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/529.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/53.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/530.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/531.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/532.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/533.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/534.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/535.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/536.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/537.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/538.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/539.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/54.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/540.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/541.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/542.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/543.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/544.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/545.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/546.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/547.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/55.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/56.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/57.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/58.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/59.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/6.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/60.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/61.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/62.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/63.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/64.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/65.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/66.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/67.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/68.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/69.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/7.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/70.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/71.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/72.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/73.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/74.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/75.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/76.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/77.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/78.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/79.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/8.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/80.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/81.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/82.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/83.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/84.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/85.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/86.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/87.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/88.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/89.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/9.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/90.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/91.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/92.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/93.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/94.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/95.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/96.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/97.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/98.dcm
#   inflating: ./test/1.2.826.0.1.3680043.25399/99.dcm
# ...
#   inflating: ./test/1.2.826.0.1.3680043.5876/249.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/25.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/250.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/251.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/252.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/253.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/254.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/255.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/256.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/257.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/258.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/259.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/26.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/260.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/261.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/262.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/263.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/264.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/265.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/266.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/267.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/268.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/269.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/27.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/270.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/271.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/272.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/273.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/274.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/275.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/276.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/277.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/278.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/279.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/28.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/280.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/281.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/282.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/283.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/284.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/285.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/286.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/287.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/288.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/289.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/29.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/290.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/291.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/292.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/293.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/294.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/295.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/296.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/297.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/298.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/299.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/3.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/30.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/300.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/301.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/302.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/303.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/304.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/305.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/306.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/307.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/308.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/309.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/31.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/310.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/311.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/312.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/313.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/314.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/315.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/316.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/317.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/318.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/319.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/32.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/320.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/321.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/322.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/323.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/324.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/325.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/326.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/327.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/328.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/329.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/33.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/330.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/331.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/332.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/333.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/334.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/335.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/336.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/337.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/338.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/339.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/34.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/340.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/341.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/342.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/343.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/344.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/345.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/346.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/347.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/348.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/349.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/35.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/350.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/351.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/352.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/353.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/354.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/355.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/356.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/357.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/358.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/359.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/36.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/360.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/361.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/362.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/363.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/364.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/365.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/366.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/367.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/368.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/369.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/37.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/370.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/371.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/372.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/373.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/374.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/375.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/376.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/377.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/378.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/379.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/38.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/380.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/381.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/382.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/383.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/384.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/385.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/386.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/387.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/388.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/389.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/39.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/390.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/391.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/392.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/393.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/394.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/395.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/396.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/397.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/398.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/399.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/4.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/40.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/400.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/401.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/402.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/403.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/404.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/405.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/406.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/407.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/408.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/409.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/41.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/410.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/411.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/412.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/413.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/414.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/415.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/416.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/417.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/418.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/419.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/42.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/420.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/421.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/422.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/423.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/424.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/425.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/426.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/427.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/428.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/429.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/43.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/430.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/431.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/432.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/433.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/434.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/435.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/436.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/437.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/438.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/439.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/44.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/440.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/441.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/442.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/443.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/444.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/445.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/446.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/447.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/448.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/449.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/45.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/450.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/451.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/452.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/453.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/454.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/455.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/456.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/457.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/458.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/46.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/47.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/48.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/49.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/5.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/50.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/51.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/52.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/53.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/54.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/55.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/56.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/57.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/58.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/59.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/6.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/60.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/61.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/62.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/63.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/64.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/65.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/66.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/67.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/68.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/69.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/7.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/70.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/71.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/72.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/73.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/74.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/75.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/76.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/77.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/78.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/79.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/8.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/80.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/81.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/82.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/83.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/84.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/85.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/86.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/87.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/88.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/89.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/9.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/90.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/91.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/92.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/93.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/94.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/95.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/96.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/97.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/98.dcm
#   inflating: ./test/1.2.826.0.1.3680043.5876/99.dcm

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import os

def download_folder_contents(folder_id, parent_path=""):
    # Create a directory for the current folder
    current_folder_path = os.path.join(parent_path, folder_id)
    os.makedirs(current_folder_path, exist_ok=True)

    # Get all files and subfolders within the current folder
    query = "'{}' in parents and trashed=false".format(folder_id)
    file_list = drive.ListFile({'q': query}).GetList()

    # Download files and recursively download subfolders
    for file in file_list:
        if file['mimeType'] == 'application/vnd.google-apps.folder':
            download_folder_contents(file['id'], current_folder_path)
        else:
            file_path = os.path.join(current_folder_path, file['title'])
            file.GetContentFile(file_path)
            print(f"Downloaded: {file_path}")

# Authenticate with Google Drive
gauth = GoogleAuth()
# gauth.LocalWebserverAuth()  # Create local webserver and auto handles authentication
gauth.CommandLineAuth()
drive = GoogleDrive(gauth)

# Main folder ID (replace 'YOUR_FOLDER_ID' with the actual ID of your main folder)
main_folder_id = '1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300'

# Start downloading the folder contents
download_folder_contents(main_folder_id)
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=127417130197-n9ocblg4m5v323l8s9nanh0euvb3dfgs.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Enter verification code: 4/1AdLIrYfyQ_TIV7Ps3SlSiMH_z-rA3n5JRKZkUAmrcwuxyvnQMkge7rWLi_s
# Authentication successful.
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold2_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold4_last (1).pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold3_last (1).pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold1_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold0_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold3_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold2_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold1_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold4_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold0_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold3_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep_fold4_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold4_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold3_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold0_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold1_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold2_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold4_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold3_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold1_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold2_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep_fold0_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold4_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold3_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold4_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold3_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold2_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold2_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold1_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold1_best.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold0_last.pth
# Downloaded: 1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq/timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep_fold0_best.pth

# %%
# !pip install timm
# !pip install albumentations
# !pip install segmentation_models_pytorch
# !pip install monai
# !pip install imageio
# !pip install pydicom
# !pip install pandas
# !pip install nibabel
# !pip install matplotlib
# !pip install torch
# !pip install cv
# !pip install pylibjpeg==1.4.0
# !pip install python_gdcm==3.0.17.1
# !pip install pylibjpeg-libjpeg
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.17.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7->timm) (12.4.127)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.9.0.80)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.11.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2024.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.5.0)
# Requirement already satisfied: segmentation_models_pytorch in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.17.1+cu121)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.7.4)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.7.1)
# Requirement already satisfied: timm==0.9.2 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (4.66.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (9.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.2.1+cu121)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation_models_pytorch) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation_models_pytorch) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation_models_pytorch) (0.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (2.31.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: monai in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.25.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->monai) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.25.2)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (2.4.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (4.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.25.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel) (24.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel) (67.7.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: cv in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: pylibjpeg==1.4.0 in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pylibjpeg==1.4.0) (1.25.2)
# Requirement already satisfied: python_gdcm==3.0.17.1 in /usr/local/lib/python3.10/dist-packages (3.0.17.1)
# Requirement already satisfied: pylibjpeg-libjpeg in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: numpy<2.0,>=1.24 in /usr/local/lib/python3.10/dist-packages (from pylibjpeg-libjpeg) (1.25.2)

# %%
import os
import sys
import ast
import cv2
import time
import timm
import timm4smp
import pickle
import random
import pydicom
import argparse
import warnings
import threading
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from glob import glob
import albumentations
import matplotlib.pyplot as plt
import segmentation_models_pytorch as smp

import torch
import torch.nn as nn
import torch.optim as optim
import torch.cuda.amp as amp
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from pylab import rcParams

# %matplotlib inline
device = torch.device('cuda')
torch.backends.cudnn.benchmark = True

timm.__version__, timm4smp.__version__
# Out:
# ('0.9.2', '0.6.12')

# %%
data_dir = './dataset'
image_size_seg = (128, 128, 128)
msk_size = image_size_seg[0]
image_size_cls = 224
n_slice_per_c = 15
n_ch = 5
image_size = 224

batch_size_seg = 1
num_workers = 0
DEBUG = False
lstm_hidden_size = 4  # Further reduced hidden size for LSTM
bottleneck_channels = 8  # Further reduced bottleneck layer channels
drop_rate = 0.
drop_rate_last = 0.3
drop_path_rate = 0.
out_dim = 1

# %%
df_test = pd.read_csv("./dataset/test.csv")
df_test
# Out:
#                          row_id           StudyInstanceUID prediction_type
# 0  1.2.826.0.1.3680043.10197_C1  1.2.826.0.1.3680043.10197              C1
# 1  1.2.826.0.1.3680043.10454_C1  1.2.826.0.1.3680043.10454              C1
# 2  1.2.826.0.1.3680043.10690_C1  1.2.826.0.1.3680043.10690              C1

# %%
if DEBUG:
    df = pd.read_csv(os.path.join(data_dir, 'train.csv')).head(1500)
    df = pd.DataFrame({
        'StudyInstanceUID': df['StudyInstanceUID'].unique().tolist()
    })
    df['image_folder'] = df['StudyInstanceUID'].apply(lambda x: os.path.join(data_dir, 'train_images', x))
else:
    df = pd.read_csv(os.path.join(data_dir, 'test.csv'))
    if df.iloc[0].row_id == '1.2.826.0.1.3680043.10197_C1':
        # test_images and test.csv are inconsistent in the dev dataset, fixing labels for the dev run.
        df = pd.DataFrame({
            "row_id": ['1.2.826.0.1.3680043.22327_C1', '1.2.826.0.1.3680043.25399_C1', '1.2.826.0.1.3680043.5876_C1'],
            "StudyInstanceUID": ['1.2.826.0.1.3680043.22327', '1.2.826.0.1.3680043.25399', '1.2.826.0.1.3680043.5876'],
            "prediction_type": ["C1", "C1", "patient_overall"]}
        )
    df = pd.DataFrame({
        'StudyInstanceUID': df['StudyInstanceUID'].unique().tolist()
    })
    df['image_folder'] = df['StudyInstanceUID'].apply(lambda x: os.path.join(data_dir, 'test', x))

df.tail()
# Out:
#             StudyInstanceUID                              image_folder
# 0  1.2.826.0.1.3680043.22327  ./dataset/test/1.2.826.0.1.3680043.22327
# 1  1.2.826.0.1.3680043.25399  ./dataset/test/1.2.826.0.1.3680043.25399
# 2   1.2.826.0.1.3680043.5876   ./dataset/test/1.2.826.0.1.3680043.5876

# %% [markdown]
# <h2>Dataset</h2>

# %%
def load_dicom(path):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    data = cv2.resize(data, (image_size_seg[0], image_size_seg[1]), interpolation = cv2.INTER_AREA)
    return data


def load_dicom_line_par(path):

    t_paths = sorted(glob(os.path.join(path, "*")), key=lambda x: int(x.split('/')[-1].split(".")[0]))

    n_scans = len(t_paths)
#     print(n_scans)
    indices = np.quantile(list(range(n_scans)), np.linspace(0., 1., image_size_seg[2])).round().astype(int)
    t_paths = [t_paths[i] for i in indices]

    images = []
    for filename in t_paths:
        images.append(load_dicom(filename))
    images = np.stack(images, -1)

    images = images - np.min(images)
    images = images / (np.max(images) + 1e-4)
    images = (images * 255).astype(np.uint8)

    return images


class SegTestDataset(Dataset):

    def __init__(self, df):
        self.df = df.reset_index()

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, index):
        row = self.df.iloc[index]


        image = load_dicom_line_par(row.image_folder)
        if image.ndim < 4:
            image = np.expand_dims(image, 0)
        image = image.astype(np.float32).repeat(3, 0)  # to 3ch
        image = image / 255.
        return torch.tensor(image).float()

# %%
dataset_seg = SegTestDataset(df)
print(f"Total number of samples in the dataset: {len(dataset_seg)}")
loader_seg = torch.utils.data.DataLoader(dataset_seg, batch_size=batch_size_seg, shuffle=False, num_workers=num_workers)
# Out:
# Total number of samples in the dataset: 3

# %%
if DEBUG:
    rcParams['figure.figsize'] = 20,8
    for i in range(2):
        f, axarr = plt.subplots(1,4)
        for p in range(4):
            idx = i*4+p
            img = dataset_seg[idx]
            img = img[:, :, :, 60]
            axarr[p].imshow(img.transpose(0, 1).transpose(1,2).squeeze())

# %%
if DEBUG:
    rcParams['figure.figsize'] = 20,8
    for i in range(2):
        f, axarr = plt.subplots(1,4)
        for p in range(4):
            idx = i*4+p
            img = dataset_seg[idx]
            img = img[:, :, 60, :]
            axarr[p].imshow(img.transpose(0, 1).transpose(1,2).squeeze())

# %%
if DEBUG:
    rcParams['figure.figsize'] = 20,8
    for i in range(2):
        f, axarr = plt.subplots(1,4)
        for p in range(4):
            idx = i*4+p
            img = dataset_seg[idx]
            img = img[:, 60, :, :]
            axarr[p].imshow(img.transpose(0, 1).transpose(1,2).squeeze())

# %% [markdown]
# <h2>Models</h2>

# %%
""" Conv3d w/ Same Padding
modified from:
https://github.com/rwightman/pytorch-image-models/blob/a2727c1bf78ba0d7b5727f5f95e37fb7f8866b1f/timm/models/layers/conv2d_same.py
https://github.com/rwightman/pytorch-image-models/blob/a2727c1bf78ba0d7b5727f5f95e37fb7f8866b1f/timm/models/layers/padding.py
"""
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import Tuple, Optional, List


# Calculate symmetric padding for a convolution
def get_padding(kernel_size: int, stride: int = 1, dilation: int = 1, **_) -> int:
    padding = ((stride - 1) + dilation * (kernel_size - 1)) // 2
    return padding


# Calculate asymmetric TensorFlow-like 'SAME' padding for a convolution
def get_same_padding(x: int, k: int, s: int, d: int):
    return max((math.ceil(x / s) - 1) * s + (k - 1) * d + 1 - x, 0)


# Can SAME padding for given args be done statically?
def is_static_pad(kernel_size: int, stride: int = 1, dilation: int = 1, **_):
    return stride == 1 and (dilation * (kernel_size - 1)) % 2 == 0


# Dynamically pad input x with 'SAME' padding for conv with specified args
def pad_same(x, k: List[int], s: List[int], d: List[int] = (1, 1, 1), value: float = 0):
    ih, iw, iz = x.size()[-3:]
    pad_h = get_same_padding(ih, k[0], s[0], d[0])
    pad_w = get_same_padding(iw, k[1], s[1], d[1])
    pad_z = get_same_padding(iz, k[2], s[2], d[2])
    if pad_h > 0 or pad_w > 0 or pad_z > 0:
        x = F.pad(x, [pad_w // 2, pad_w - pad_w // 2, pad_h // 2, pad_h - pad_h // 2, pad_z // 2, pad_z - pad_z // 2], value=value)
    return x


def get_padding_value(padding, kernel_size, **kwargs) -> Tuple[Tuple, bool]:
    dynamic = False
    if isinstance(padding, str):
        # for any string padding, the padding will be calculated for you, one of three ways
        padding = padding.lower()
        if padding == 'same':
            # TF compatible 'SAME' padding, has a performance and GPU memory allocation impact
            if is_static_pad(kernel_size, **kwargs):
                # static case, no extra overhead
                padding = get_padding(kernel_size, **kwargs)
            else:
                # dynamic 'SAME' padding, has runtime/GPU memory overhead
                padding = 0
                dynamic = True
        elif padding == 'valid':
            # 'VALID' padding, same as padding=0
            padding = 0
        else:
            # Default to PyTorch style 'same'-ish symmetric padding
            padding = get_padding(kernel_size, **kwargs)
    return padding, dynamic


def conv3d_same(
        x, weight: torch.Tensor, bias: Optional[torch.Tensor] = None, stride: Tuple[int, int, int] = (1, 1, 1),
        padding: Tuple[int, int, int] = (0, 0, 0), dilation: Tuple[int, int, int] = (1, 1, 1), groups: int = 1):
    x = pad_same(x, weight.shape[-3:], stride, dilation)
    return F.conv3d(x, weight, bias, stride, (0, 0, 0), dilation, groups)


class Conv3dSame(nn.Conv3d):
    """ Tensorflow like 'SAME' convolution wrapper for 3d convolutions
    """

    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0, dilation=1, groups=1, bias=True):
        super(Conv3dSame, self).__init__(
            in_channels, out_channels, kernel_size, stride, 0, dilation, groups, bias)

    def forward(self, x):
        return conv3d_same(x, self.weight, self.bias, self.stride, self.padding, self.dilation, self.groups)


def create_conv3d_pad(in_chs, out_chs, kernel_size, **kwargs):
    padding = kwargs.pop('padding', '')
    kwargs.setdefault('bias', False)
    padding, is_dynamic = get_padding_value(padding, kernel_size, **kwargs)
    if is_dynamic:
        return Conv3dSame(in_chs, out_chs, kernel_size, **kwargs)
    else:
        return nn.Conv3d(in_chs, out_chs, kernel_size, padding=padding, **kwargs)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from segmentation_models_pytorch.base import modules as md


class PAB(nn.Module):
    def __init__(self, in_channels, out_channels, pab_channels=64):
        super(PAB, self).__init__()
        # Series of 1x1 conv to generate attention feature maps
        self.pab_channels = pab_channels
        self.in_channels = in_channels
        self.top_conv = nn.Conv2d(in_channels, pab_channels, kernel_size=1)
        self.center_conv = nn.Conv2d(in_channels, pab_channels, kernel_size=1)
        self.bottom_conv = nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1)
        self.map_softmax = nn.Softmax(dim=1)
        self.out_conv = nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1)

    def forward(self, x):
        bsize = x.size()[0]
        h = x.size()[2]
        w = x.size()[3]
        d = x.size()[4]
        x_top = self.top_conv(x)
        x_center = self.center_conv(x)
        x_bottom = self.bottom_conv(x)

        x_top = x_top.flatten(2)
        x_center = x_center.flatten(2).transpose(1, 2)
        x_bottom = x_bottom.flatten(2).transpose(1, 2)
        sp_map = torch.matmul(x_center, x_top)
        sp_map = self.map_softmax(sp_map.view(bsize, -1)).view(bsize, h*w*d, h*w*d)
        sp_map = torch.matmul(sp_map, x_bottom)
        sp_map = sp_map.reshape(bsize, self.in_channels, h, w, d)
        x = x + sp_map
        x = self.out_conv(x)
        # print('x_top',x_top.shape,'x_center',x_center.shape,'x_bottom',x_bottom.shape,'x',x.shape,'sp_map',sp_map.shape)
        return x


class MFAB(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels, use_batchnorm=True, reduction=16):
        # MFAB is just a modified version of SE-blocks, one for skip, one for input
        super(MFAB, self).__init__()
        self.hl_conv = nn.Sequential(
            md.Conv2dReLU(
                in_channels,
                in_channels,
                kernel_size=3,
                padding=1,
                use_batchnorm=use_batchnorm,
            ),
            md.Conv2dReLU(
                in_channels,
                skip_channels,
                kernel_size=1,
                use_batchnorm=use_batchnorm,
            ),
        )
        reduced_channels = max(1, skip_channels // reduction)
        self.SE_ll = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(skip_channels, reduced_channels, 1),
            nn.ReLU(inplace=True),
            nn.Conv2d(reduced_channels, skip_channels, 1),
            nn.Sigmoid(),
        )
        self.SE_hl = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(skip_channels, reduced_channels, 1),
            nn.ReLU(inplace=True),
            nn.Conv2d(reduced_channels, skip_channels, 1),
            nn.Sigmoid(),
        )
        self.conv1 = md.Conv2dReLU(
            skip_channels + skip_channels,  # we transform C-prime form high level to C from skip connection
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.conv2 = md.Conv2dReLU(
            out_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )

    def forward(self, x, skip=None):
        x = self.hl_conv(x)
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        attention_hl = self.SE_hl(x)
        if skip is not None:
            attention_ll = self.SE_ll(skip)
            attention_hl = attention_hl + attention_ll
            x = x * attention_hl
            x = torch.cat([x, skip], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x


class DecoderBlock(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels, use_batchnorm=True):
        super().__init__()
        self.conv1 = md.Conv2dReLU(
            in_channels + skip_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.conv2 = md.Conv2dReLU(
            out_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )

    def forward(self, x, skip=None):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if skip is not None:
            x = torch.cat([x, skip], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x


class MAnetDecoder(nn.Module):
    def __init__(
        self,
        encoder_channels,
        decoder_channels,
        n_blocks=5,
        reduction=16,
        use_batchnorm=True,
        pab_channels=64,
    ):
        super().__init__()

        if n_blocks != len(decoder_channels):
            raise ValueError(
                "Model depth is {}, but you provide `decoder_channels` for {} blocks.".format(
                    n_blocks, len(decoder_channels)
                )
            )

        # remove first skip with same spatial resolution
        encoder_channels = encoder_channels[1:]

        # reverse channels to start from head of encoder
        encoder_channels = encoder_channels[::-1]

        # computing blocks input and output channels
        head_channels = encoder_channels[0]
        in_channels = [head_channels] + list(decoder_channels[:-1])
        skip_channels = list(encoder_channels[1:]) + [0]
        out_channels = decoder_channels

        self.center = PAB(head_channels, head_channels, pab_channels=pab_channels)

        # combine decoder keyword arguments
        kwargs = dict(use_batchnorm=use_batchnorm)  # no attention type here
        blocks = [
            MFAB(in_ch, skip_ch, out_ch, reduction=reduction, **kwargs)
            if skip_ch > 0
            else DecoderBlock(in_ch, skip_ch, out_ch, **kwargs)
            for in_ch, skip_ch, out_ch in zip(in_channels, skip_channels, out_channels)
        ]
        # for the last we dont have skip connection -> use simple decoder block
        self.blocks = nn.ModuleList(blocks)

    def forward(self, *features):

        features = features[1:]  # remove first skip with same spatial resolution
        features = features[::-1]  # reverse channels to start from head of encoder

        head = features[0]
        skips = features[1:]

        x = self.center(head)
        for i, decoder_block in enumerate(self.blocks):
            skip = skips[i] if i < len(skips) else None
            x = decoder_block(x, skip)

        return x

# %%
from timm4smp.models.layers.conv2d_same import Conv2dSame
from timm4smp.models import create_model

def convert_3d(module):

    module_output = module
    if isinstance(module, torch.nn.BatchNorm2d):
        module_output = torch.nn.BatchNorm3d(
            module.num_features,
            module.eps,
            module.momentum,
            module.affine,
            module.track_running_stats,
        )
        if module.affine:
            with torch.no_grad():
                module_output.weight = module.weight
                module_output.bias = module.bias
        module_output.running_mean = module.running_mean
        module_output.running_var = module.running_var
        module_output.num_batches_tracked = module.num_batches_tracked
        if hasattr(module, "qconfig"):
            module_output.qconfig = module.qconfig

    elif isinstance(module, Conv2dSame):
        module_output = Conv3dSame(
            in_channels=module.in_channels,
            out_channels=module.out_channels,
            kernel_size=module.kernel_size[0],
            stride=module.stride[0],
            padding=module.padding[0],
            dilation=module.dilation[0],
            groups=module.groups,
            bias=module.bias is not None,
        )
        module_output.weight = torch.nn.Parameter(module.weight.unsqueeze(-1).repeat(1,1,1,1,module.kernel_size[0]))

    elif isinstance(module, torch.nn.Conv2d):
        module_output = torch.nn.Conv3d(
            in_channels=module.in_channels,
            out_channels=module.out_channels,
            kernel_size=module.kernel_size[0],
            stride=module.stride[0],
            padding=module.padding[0],
            dilation=module.dilation[0],
            groups=module.groups,
            bias=module.bias is not None,
            padding_mode=module.padding_mode
        )
        module_output.weight = torch.nn.Parameter(module.weight.unsqueeze(-1).repeat(1,1,1,1,module.kernel_size[0]))

    elif isinstance(module, torch.nn.MaxPool2d):
        module_output = torch.nn.MaxPool3d(
            kernel_size=module.kernel_size,
            stride=module.stride,
            padding=module.padding,
            dilation=module.dilation,
            ceil_mode=module.ceil_mode,
        )
    elif isinstance(module, torch.nn.AvgPool2d):
        module_output = torch.nn.AvgPool3d(
            kernel_size=module.kernel_size,
            stride=module.stride,
            padding=module.padding,
            ceil_mode=module.ceil_mode,
        )

    for name, child in module.named_children():
        module_output.add_module(
            name, convert_3d(child)
        )
    del module

    return module_output



class TimmSegModel(nn.Module):
    def __init__(self, backbone, segtype='MAnet', pretrained=False):
        super(TimmSegModel, self).__init__()

        self.encoder = timm4smp.models.create_model(
            backbone,
            in_chans=3,
            features_only=True,
            pretrained=pretrained
        )

        # num_input_channels = saved_model['encoder.bn1.running_mean'].shape[0]
        # self.encoder.bn1 = nn.BatchNorm2d(num_features=64)
        g = self.encoder(torch.rand(1, 3, 64, 64))
        encoder_channels = [1] + [_.shape[1] for _ in g]
        decoder_channels = [256, 128, 64, 32, 16]
        if segtype == 'MAnet':
            self.decoder =  MAnetDecoder(
                encoder_channels=encoder_channels[:n_blocks+1],
                decoder_channels=decoder_channels[:n_blocks],
                n_blocks=n_blocks,
            )
        self.segmentation_head = nn.Conv2d(decoder_channels[n_blocks-1], 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

    def forward(self,x):
        global_features = [0] + self.encoder(x)[:n_blocks]
        seg_features = self.decoder(*global_features)
        seg_features = self.segmentation_head(seg_features)
        return seg_features


class TimmModel(nn.Module):
    def __init__(self, backbone, pretrained=False):
        super(TimmModel, self).__init__()

        self.encoder = timm.create_model(
            backbone,
            in_chans=in_chans,
            features_only=True,  # We want the intermediate features, not the final classification layer
            pretrained=True
        )

        if 'vgg' in backbone:
            hdim = 512 # The number of channels after the final conv layer
        elif 'convnext' in backbone:
            hdim = self.encoder.feature_info[-1]['num_chs']  # Get the number of channels in the last feature map
        else:
            raise ValueError(f"Backbone {backbone} not supported")

        # Add a bottleneck layer to reduce the number of channels
        self.bottleneck = nn.Conv2d(hdim, bottleneck_channels, kernel_size=1)  # Reduce to bottleneck_channels
        hdim = bottleneck_channels

        self.lstm = nn.LSTM(hdim * 7 * 7, lstm_hidden_size, num_layers=1, dropout=drop_rate, bidirectional=True, batch_first=True)
        self.head = nn.Sequential(
            nn.Linear(2 * lstm_hidden_size, 8),  # Further reduce fully connected layer size
            nn.BatchNorm1d(8),
            nn.Dropout(drop_rate_last),
            nn.LeakyReLU(0.1),
            nn.Linear(8, out_dim),
        )
        self.lstm2 = nn.LSTM(hdim * 7 * 7, lstm_hidden_size, num_layers=1, dropout=drop_rate, bidirectional=True, batch_first=True)
        self.head2 = nn.Sequential(
            nn.Linear(2 * lstm_hidden_size, 8),
            nn.BatchNorm1d(8),
            nn.Dropout(drop_rate_last),
            nn.LeakyReLU(0.1),
            nn.Linear(8, 1),
        )

    def forward(self, x):  # (bs, nc*7, ch, sz, sz)
        bs = x.shape[0]
        #print(f"Input shape: {x.shape}")

        x = x.view(bs * n_slice_per_c * 7, in_chans, image_size, image_size)
        #print(f"Shape after view: {x.shape}")

        feat = self.encoder(x)[-1]  # Get the last feature map
        #print(f"Shape after encoder features: {feat.shape}")

        # Apply the bottleneck layer
        feat = self.bottleneck(feat)
        #print(f"Shape after bottleneck: {feat.shape}")

        # Flatten the spatial dimensions
        feat = feat.reshape(feat.size(0), -1)  # This will be [bs * n_slice_per_c * 7, bottleneck_channels*7*7]

        # Reshape to [bs, n_slice_per_c * 7, bottleneck_channels*7*7]
        feat = feat.reshape(bs, n_slice_per_c * 7, -1)
        #print(f"Shape before LSTM: {feat.shape}")

        feat1, _ = self.lstm(feat)
        #print(f"Shape after LSTM feat1: {feat1.shape}")

        feat1 = feat1.contiguous().view(bs * n_slice_per_c * 7, 2 * lstm_hidden_size)
        feat2, _ = self.lstm2(feat)
        #print(f"Shape after LSTM feat2: {feat2.shape}")

        return self.head(feat1), self.head2(feat2[:, 0])




class Timm1BoneModel(nn.Module):
    def __init__(self, backbone, image_size, pretrained=False):
        super(Timm1BoneModel, self).__init__()
        self.image_size = image_size

        self.encoder = timm.create_model(
            backbone,
            in_chans=in_chans,
            num_classes=1,
            features_only=False,
            drop_rate=0,
            drop_path_rate=0,
            pretrained=pretrained
        )

        if 'resnet' in backbone:
            hdim = self.encoder.fc.out_features
            self.encoder.classifier = nn.Identity()
        elif 'convnext' in backbone or 'nfnet' in backbone:
            hdim = self.encoder.head.fc.in_features
            self.encoder.head.fc = nn.Identity()

        self.lstm = nn.LSTM(hdim, 256, num_layers=2, dropout=0, bidirectional=True, batch_first=True)
        self.head = nn.Sequential(
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.Dropout(0),
            nn.LeakyReLU(0.1),
            nn.Linear(256, 1),
        )


    def forward(self, x):  # (bs, nslice, ch, sz, sz)
        bs = x.shape[0]
        x = x.view(bs * n_slice_per_c, in_chans, self.image_size, self.image_size)
        feat = self.encoder(x)
        feat = feat.view(bs, n_slice_per_c, -1)
        feat, _ = self.lstm(feat)
        feat = feat.contiguous().view(bs * n_slice_per_c, -1)
        feat = self.head(feat)
        feat = feat.view(bs, n_slice_per_c).contiguous()

        return feat

# %% [markdown]
# <h2>Load Models</h2>

# %%
models_seg = []

kernel_type = 'timm3d_manet_unet4b_128_128_128_dsv2_flip12_shift333p7_gd1p5_bs4_lr3e4_20x50ep'
backbone = 'resnet18d'
model_dir_seg = '1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1izp7p4JAD8cK5cSUHrqyA-pn171k0_Wq'
n_blocks = 4
for fold in range(5):
    model = TimmSegModel(backbone, pretrained=False)
    model = convert_3d(model)
    model = model.to(device)
    load_model_file = os.path.join(model_dir_seg, f'{kernel_type}_fold{fold}_best.pth')
    sd = torch.load(load_model_file)
    if 'model_state_dict' in sd.keys():
        sd = sd['model_state_dict']
    sd = {k[7:] if k.startswith('module.') else k: sd[k] for k in sd.keys()}
    # Assuming `model` is your PyTorch model
    # for name, param in model.named_parameters():
    #     print(f"Parameter name: {name}, Size: {param.size()}")

    model.load_state_dict(sd, strict=False)
    model.eval()
    models_seg.append(model)

len(models_seg)
# Out:
# 5

# %%
kernel_type = '0920_1bonev2_resnet18_224_15_6ch_augv2_mixupp5_drl3_rov1p2_bs8_lr23e5_eta23e6_50ep'
model_dir_cls = '1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/1a02yEixVwlH8U4q69dY_pv9tK6BhuMTk/'
backbone = 'resnet18'
in_chans = 6
models_cls1 = []

for fold in range(5):
    model = Timm1BoneModel(backbone, image_size=224, pretrained=False)
    load_model_file = os.path.join(model_dir_cls, f'{kernel_type}_fold{fold}_best.pth')
    sd = torch.load(load_model_file, map_location='cpu')
    if 'model_state_dict' in sd.keys():
        sd = sd['model_state_dict']
    sd = {k[7:] if k.startswith('module.') else k: sd[k] for k in sd.keys()}
    model.load_state_dict(sd, strict=True)
    model = model.to(device)
    model.eval()
    models_cls1.append(model)

len(models_cls1)
# Out:
# 5

# %%
kernel_type = '0920_2d_lstmv22headv2_vgg_224_15_6ch_8flip_augv2_drl3_rov1p2_rov3p2_bs4_lr6e5_eta6e6_lw151_50ep'
model_dir_cls = '1dTxO27AQ2lnnRvcBz5E-hwhhwQ-mM300/10G5-hJQ2Odjx3aFOQrEy2iCVFQw6knV9/'
backbone = 'vgg16'
in_chans = 6
models_cls2 = []

for fold in range(5):
    model = TimmModel(backbone, pretrained=False)
    model = model.to(device)
    load_model_file = os.path.join(model_dir_cls, f'{kernel_type}_fold{fold}_best.pth')
    sd = torch.load(load_model_file)
    if 'model_state_dict' in sd.keys():
        sd = sd['model_state_dict']
    sd = {k[7:] if k.startswith('module.') else k: sd[k] for k in sd.keys()}
    model.load_state_dict(sd, strict=True)
    model.eval()
    models_cls2.append(model)

len(models_cls2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/553M [00:00<?, ?B/s]
# 5

# %%
# !nvidia-smi

# %%
def load_bone(msk, cid, t_paths, cropped_images):
    n_scans = len(t_paths)
    bone = []
    try:
        msk_b = msk[cid] > 0.2
        msk_c = msk[cid] > 0.05

        x = np.where(msk_b.sum(1).sum(1) > 0)[0]
        y = np.where(msk_b.sum(0).sum(1) > 0)[0]
        z = np.where(msk_b.sum(0).sum(0) > 0)[0]

        if len(x) == 0 or len(y) == 0 or len(z) == 0:
            x = np.where(msk_c.sum(1).sum(1) > 0)[0]
            y = np.where(msk_c.sum(0).sum(1) > 0)[0]
            z = np.where(msk_c.sum(0).sum(0) > 0)[0]

        x1, x2 = max(0, x[0] - 1), min(msk.shape[1], x[-1] + 1)
        y1, y2 = max(0, y[0] - 1), min(msk.shape[2], y[-1] + 1)
        z1, z2 = max(0, z[0] - 1), min(msk.shape[3], z[-1] + 1)
        zz1, zz2 = int(z1 / msk_size * n_scans), int(z2 / msk_size * n_scans)

        inds = np.linspace(zz1 ,zz2-1 ,n_slice_per_c).astype(int)
        inds_ = np.linspace(z1 ,z2-1 ,n_slice_per_c).astype(int)
        for sid, (ind, ind_) in enumerate(zip(inds, inds_)):

            msk_this = msk[cid, :, :, ind_]

            images = []
            for i in range(-n_ch//2+1, n_ch//2+1):
                try:
                    dicom = pydicom.read_file(t_paths[ind+i])
                    images.append(dicom.pixel_array)
                except:
                    images.append(np.zeros((512, 512)))

            data = np.stack(images, -1)
            data = data - np.min(data)
            data = data / (np.max(data) + 1e-4)
            data = (data * 255).astype(np.uint8)
            msk_this = msk_this[x1:x2, y1:y2]
            xx1 = int(x1 / msk_size * data.shape[0])
            xx2 = int(x2 / msk_size * data.shape[0])
            yy1 = int(y1 / msk_size * data.shape[1])
            yy2 = int(y2 / msk_size * data.shape[1])
            data = data[xx1:xx2, yy1:yy2]
            data = np.stack([cv2.resize(data[:, :, i], (image_size_cls, image_size_cls), interpolation = cv2.INTER_LINEAR) for i in range(n_ch)], -1)
            msk_this = (msk_this * 255).astype(np.uint8)
            msk_this = cv2.resize(msk_this, (image_size_cls, image_size_cls), interpolation = cv2.INTER_LINEAR)

            data = np.concatenate([data, msk_this[:, :, np.newaxis]], -1)

            bone.append(torch.tensor(data))

    except:
        for sid in range(n_slice_per_c):
            bone.append(torch.ones((image_size_cls, image_size_cls, n_ch+1)).int())

    cropped_images[cid] = torch.stack(bone, 0)


def load_cropped_images(msk, image_folder, n_ch=n_ch):

    t_paths = sorted(glob(os.path.join(image_folder, "*")), key=lambda x: int(x.split('/')[-1].split(".")[0]))
    for cid in range(7):
        threads[cid] = threading.Thread(target=load_bone, args=(msk, cid, t_paths, cropped_images))
        threads[cid].start()
    for cid in range(7):
        threads[cid].join()

    return torch.cat(cropped_images, 0)

# %% [markdown]
# <h2>Predict</h2>

# %%
outputs1 = []
outputs2 = []

bar = tqdm(loader_seg)
with torch.no_grad():
    for batch_id, (images) in enumerate(bar):
        images = images.cuda()

        # SEG
        pred_masks = []
        for model in models_seg:
            pmask = model(images).sigmoid()
            pred_masks.append(pmask)
        pred_masks = torch.stack(pred_masks, 0).mean(0).cpu().numpy()

        # Build cls input
        cls_inp = []
        threads = [None] * 7
        cropped_images = [None] * 7

        for i in range(pred_masks.shape[0]):
            row = df.iloc[batch_id*batch_size_seg+i]
            cropped_images = load_cropped_images(pred_masks[i], row.image_folder)
            cls_inp.append(cropped_images.permute(0, 3, 1, 2).float() / 255.)
        cls_inp = torch.stack(cls_inp, 0).to(device)  # (1, 105, 6, 224, 224)

        pred_cls1, pred_cls2 = [], []
        # CLS 2
        for _, model in enumerate(models_cls2):
            logits, logits2 = model(cls_inp)
            pred_cls1.append(logits.sigmoid().view(-1, 7, n_slice_per_c))
            pred_cls2.append(logits2.sigmoid())

        # CLS 1
        cls_inp = cls_inp.view(7, 15, 6, image_size_cls, image_size_cls).contiguous()
        for _, model in enumerate(models_cls1):
            logits = model(cls_inp)
            pred_cls1.append(logits.sigmoid().view(-1, 7, n_slice_per_c))

        pred_cls1 = torch.stack(pred_cls1, 0).mean(0)
        pred_cls2 = torch.stack(pred_cls2, 0).mean(0)
        outputs1.append(pred_cls1.cpu())
        outputs2.append(pred_cls2.cpu())
# Out:
# 100%|██████████| 3/3 [00:30<00:00, 10.28s/it]

# %% [markdown]
# <h2>Outputs</h2>

# %%
outputs1 = torch.cat(outputs1)
outputs2 = torch.cat(outputs2)

# %%
PRED1 = (outputs1.mean(-1)).clamp(0.0001, 0.9999)
PRED2 = (outputs2.view(-1)).clamp(0.0001, 0.9999)

# %%
row_ids = []
for _, row in df.iterrows():
    for i in range(7):
        row_ids.append(row.StudyInstanceUID + f'_C{i+1}')
    row_ids.append(row.StudyInstanceUID + '_patient_overall')

# %%
df_sub = pd.DataFrame({
    'row_id': row_ids,
    'fractured': torch.cat([PRED1, PRED2.unsqueeze(1)], 1).view(-1),
})

# %%
df_sub.to_csv('submissionmanet.csv', index=False)

# %%
df_sub
# Out:
#                                        row_id  fractured
# 0                1.2.826.0.1.3680043.22327_C1   0.187289
# 1                1.2.826.0.1.3680043.22327_C2   0.203229
# 2                1.2.826.0.1.3680043.22327_C3   0.189296
# 3                1.2.826.0.1.3680043.22327_C4   0.187159
# 4                1.2.826.0.1.3680043.22327_C5   0.202202
# 5                1.2.826.0.1.3680043.22327_C6   0.373940
# 6                1.2.826.0.1.3680043.22327_C7   0.330385
# 7   1.2.826.0.1.3680043.22327_patient_overall   0.504278
# 8                1.2.826.0.1.3680043.25399_C1   0.173886
# 9                1.2.826.0.1.3680043.25399_C2   0.201053
# 10               1.2.826.0.1.3680043.25399_C3   0.188193
# 11               1.2.826.0.1.3680043.25399_C4   0.181308
# 12               1.2.826.0.1.3680043.25399_C5   0.201081
# 13               1.2.826.0.1.3680043.25399_C6   0.217006
# 14               1.2.826.0.1.3680043.25399_C7   0.228680
# 15  1.2.826.0.1.3680043.25399_patient_overall   0.497999
# 16                1.2.826.0.1.3680043.5876_C1   0.173338
# 17                1.2.826.0.1.3680043.5876_C2   0.223466
# 18                1.2.826.0.1.3680043.5876_C3   0.171832
# 19                1.2.826.0.1.3680043.5876_C4   0.173690
# 20                1.2.826.0.1.3680043.5876_C5   0.179349
# 21                1.2.826.0.1.3680043.5876_C6   0.249863
# 22                1.2.826.0.1.3680043.5876_C7   0.291205
# 23   1.2.826.0.1.3680043.5876_patient_overall   0.504278
